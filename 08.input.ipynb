# %%
print("hello")
# Out:
# hello

# %%
input("Introdu un numar")
# Out:
# '32'

# %%
x = input("Introdu un numar")
print("Ai introdus:", x)
# Out:
# Ai introdus: 321

# %%
x = input("Introdu un numar")
if not x:
    print("Nu ai introdus nimic")
else:
    print("Ai introdus", x)
# Out:
# Ai introdus 321

# %%
x = input("Introdu un numar")
if  x:
    print("Ai introdus", x)
else:
    print("Nu ai introdus nimic")
# Out:
# Ai introdus ddas
