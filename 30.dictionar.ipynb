# %%
#.        0, 1, 2,    3
a_list = [1, 2, 3, "blue"]
print(type(a_list), len(a_list))
# Out:
# <class 'list'> 4

# %%
a_dict = {"k1":1, "k2":2, "k3":3, "k4":"blue"}
print(type(a_dict), len(a_dict))
# Out:
# <class 'dict'> 4

# %%
a_list = ["rosu", "verde", "albastru"]
len(a_list)
print(a_list[0])
# Out:
# rosu

# %%
a_dict = {"sange":"rosu", "iarba":"verde", "cer": "albastru"}
len(a_dict)
print(a_dict["sange"])
# Out:
# rosu

# %%
a_dict = {"sange":"rosu", "iarba":"verde", "cer": "albastru"}
len(a_dict)
print(a_dict["rosu"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 3
#       1 a_dict = {"sange":"rosu", "iarba":"verde", "cer": "albastru"}
#       2 len(a_dict)
# ----> 3 print(a_dict["rosu"])
#
# KeyError: 'rosu'

# %%
a_dict = {"sange":"rosu", "iarba":"verde", "cer": "albastru"}
for i in a_dict:
    print("cheia=", i, "valoare=", a_dict[i])
# Out:
# cheia= sange valoare= rosu
# cheia= iarba valoare= verde
# cheia= cer valoare= albastru

# %%
a_dict.keys()
# Out:
# dict_keys(['sange', 'iarba', 'cer'])

# %%
a_dict.values()
# Out:
# dict_values(['rosu', 'verde', 'albastru'])

# %%
a_dict = {"sange":"rosu", "iarba":"verde", "cer": "albastru"}
## EDITARE
a_dict["sange"] = "negru"
print(a_dict)
# Out:
# {'sange': 'negru', 'iarba': 'verde', 'cer': 'albastru'}

# %%
a_dict = {"sange":"rosu", "iarba":"verde", "cer": "albastru"}
## ADAUGARE
a_dict["tricou"] = "galben"
print(a_dict)
# Out:
# {'sange': 'rosu', 'iarba': 'verde', 'cer': 'albastru', 'tricou': 'galben'}

# %%
# cheile trebuie sa fie unice
a_dict = {"sange":"rosu", "iarba":"verde", "cer": "albastru", "cer":"gri"}
print(a_dict)
# Out:
# {'sange': 'rosu', 'iarba': 'verde', 'cer': 'gri'}

# %%
a_dict = {"sange":"rosu", "iarba":"verde", 30: "albastru", "cer":"gri"}
print(a_dict)
# Out:
# {'sange': 'rosu', 'iarba': 'verde', 30: 'albastru', 'cer': 'gri'}

# %%
a_dict[30]
# Out:
# 'albastru'

# %%
a_dict = {("sange", "rochie"):"rosu", "iarba":"verde", 30: "albastru", "cer":"gri"}
print(a_dict)
# Out:
# {('sange', 'rochie'): 'rosu', 'iarba': 'verde', 30: 'albastru', 'cer': 'gri'}

# %%
a_dict[('sange', 'rochie')]
# Out:
# 'rosu'

# %%
a_dict = {["sange", "rochie"]:"rosu", "iarba":"verde", 30: "albastru", "cer":"gri"}
print(a_dict)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 a_dict = {["sange", "rochie"]:"rosu", "iarba":"verde", 30: "albastru", "cer":"gri"}
#       2 print(a_dict)
#
# TypeError: cannot use 'list' as a dict key (unhashable type: 'list')

# %%
del a_dict["iarba"]

# %%
a_dict
# Out:
# {('sange', 'rochie'): 'rosu', 30: 'albastru', 'cer': 'gri'}

# %%
x = 10
print(x)
# Out:
# 10

# %%
del x

# %%
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 print(x)
#
# NameError: name 'x' is not defined
