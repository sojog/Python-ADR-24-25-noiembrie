# %%
print(range(10))
# Out:
# range(0, 10)

# %%
range(10)
# Out:
# range(0, 10)

# %%
x = 10
x
# Out:
# 10

# %%
range(2, 10)
# Out:
# range(2, 10)

# %%
for i in range(10):
    print("i", i)
# Out:
# i 0
# i 1
# i 2
# i 3
# i 4
# i 5
# i 6
# i 7
# i 8
# i 9

# %%
for i in range(3, 10):
    print("i", i, type(i))
# Out:
# i 3 <class 'int'>
# i 4 <class 'int'>
# i 5 <class 'int'>
# i 6 <class 'int'>
# i 7 <class 'int'>
# i 8 <class 'int'>
# i 9 <class 'int'>

# %%
for i in range(3, 10, 2):
    print("i", i)
# Out:
# i 3
# i 5
# i 7
# i 9

# %%
for i in range(3, 10):
    print("i", i)
# Out:
# i 3
# i 4
# i 5
# i 6
# i 7
# i 8
# i 9

# %%
for i in range(10, 3):
    print("i", i)

# %%
for i in range(10, 3, -1):
    print("i", i)
# Out:
# i 10
# i 9
# i 8
# i 7
# i 6
# i 5
# i 4

# %%
for i in range(5):
    print("Salutare")
# Out:
# Salutare
# Salutare
# Salutare
# Salutare
# Salutare

# %%
for i in range(5):
    nr = input("Introdu un numar")
    nr = int(nr)
    if nr % 2 == 0:
        print("Par")
    else:
        print("Impar")
# Out:
# Par
# Impar
# Par
# Impar
# Par

# %%
3
