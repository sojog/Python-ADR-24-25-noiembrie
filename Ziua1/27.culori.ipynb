# %%
with open("26.culori.txt") as file_reader:
    print(file_reader.readable())
# Out:
# True

# %%
with open("26.culori.txt") as file_reader:
    print(file_reader.read())
# Out:
# alb
# verde
# rosu
# negru

# %%
with open("26.culori.txt") as file_reader:
    print(file_reader.readlines())
# Out:
# ['alb\n', 'verde\n', 'rosu\n', 'negru']

# %%
with open("26.culori.txt") as file_reader:
    print(file_reader.readline())
    print(file_reader.readline())
# Out:
# alb
#
# verde
