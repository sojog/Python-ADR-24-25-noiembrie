# %%
with open("22.preturi.txt", "r") as file_handler:
    text = file_handler.read()
    print(text, "type(text)", type(text))
# Out:
# 100, 200, 1787872, 100, 200, 300 type(text) <class 'str'>

# %%
lista_preturi = text.split(", ")
print(lista_preturi, type(lista_preturi))
# Out:
# ['100', '200', '1787872', '100', '200', '300'] <class 'list'>

# %%
for p in lista_preturi:
    print("type(p)", type(p))
# Out:
# type(p) <class 'str'>
# type(p) <class 'str'>
# type(p) <class 'str'>
# type(p) <class 'str'>
# type(p) <class 'str'>
# type(p) <class 'str'>

# %%
for p in lista_preturi:
    pret_cu_tv = int(p) * 1.21
    print(pret_cu_tv)
# Out:
# 121.0
# 242.0
# 2163325.12
# 121.0
# 242.0
# 363.0

# %%
preturi_cu_tva = ""
for p in lista_preturi:
    pret_cu_tva = int(p) * 1.21
    preturi_cu_tva += pret_cu_tva
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       2 for p in lista_preturi:
#       3     pret_cu_tva = int(p) * 1.21
# ----> 4     preturi_cu_tva += pret_cu_tva
#
# TypeError: can only concatenate str (not "float") to str

# %%
"213" + 10.0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 "213" + 10.0
#
# TypeError: can only concatenate str (not "float") to str

# %%
"213" + str(10.0)
# Out:
# '21310.0'

# %%
preturi_cu_tva = ""
for p in lista_preturi:
    pret_cu_tva = int(p) * 1.21
    if preturi_cu_tva:
        preturi_cu_tva = preturi_cu_tva + ", "+ str(pret_cu_tva)
    else:
        preturi_cu_tva = preturi_cu_tva + str(pret_cu_tva)
print(preturi_cu_tva)
# Out:
# 121.0, 242.0, 2163325.12, 121.0, 242.0, 363.0

# %%
with open("25.preturi_cu_tva.txt", "w") as file_handler:
    file_handler.write(preturi_cu_tva)
