# %%
## Parametru default
def putere(x, p=2):
    return x ** p

# %%
putere(10, 3)
# Out:
# 1000

# %%
putere(10)
# Out:
# 100

# %%
putere()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 putere()
#
# TypeError: putere() missing 1 required positional argument: 'x'

# %%
def suma_numerelor(*args):
    print("args:", args, type(args))

# %%
suma_numerelor()
# Out:
# args: () <class 'tuple'>

# %%
suma_numerelor(1, 2, 3, )
# Out:
# args: (1, 2, 3) <class 'tuple'>

# %%
print()

# %%
print(213, 312, 321, 321)
# Out:
# 213 312 321 321

# %%
def suma_numerelor(*args, **kargs):
    print("args:", args, type(args))
    print("kargs:", kargs, type(kargs))

# %%
suma_numerelor(20, 30)
# Out:
# args: (20, 30) <class 'tuple'>
# kargs: {} <class 'dict'>

# %%
suma_numerelor(20, 30, dsa=12)
# Out:
# args: (20, 30) <class 'tuple'>
# kargs: {'dsa': 12} <class 'dict'>

# %%
print(1, 2, 3)
# Out:
# 1 2 3

# %%
print(1, 2, 3, sep="***")
# Out:
# 1***2***3

# %%
print(1, 2, 3, sep="***", end="=====")
print(1, 2, 3, sep="***")
# Out:
# 1***2***3=====1***2***3
