# %%
x = True
y = True

print(not x)
# Out:
# False

# %%
! x
# Out:
# zsh:1: command not found: x

# %%
x = True
y = True

print(x and y)
# Out:
# True

# %%
x = True
y = True

print(x or y)
# Out:
# True

# %%
x = True
y = False

print(x and y)
# Out:
# False

# %%
x = False
y = True

print(x and y)
# Out:
# False

# %%
x = False
y = False

print(x and y)
# Out:
# False

# %%
x = True
y = True

print(x or y)
# Out:
# True

# %%
x = True
y = False

print(x or y)
# Out:
# True

# %%
x = False
y = True

print(x or y)
# Out:
# True

# %%
x = False
y = False

print(x or y)
# Out:
# False

# %%
x = False
y = False

print(x or y)
