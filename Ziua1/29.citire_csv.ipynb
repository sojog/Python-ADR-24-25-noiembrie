# %%
with open("28.valori.csv", "r") as file_reader:
    lines = file_reader.readlines()

# %%
for l in lines:
    print("linie:", l)
# Out:
# linie: culori,varste,temperaturi
#
# linie: rosu,30,18
#
# linie: verde,40,25

# %%
for l in lines:
    print("linie:", l.split(","))
# Out:
# linie: ['culori', 'varste', 'temperaturi\n']
# linie: ['rosu', '30', '18\n']
# linie: ['verde', '40', '25']

# %%
import csv

# %%
with open("28.valori.csv", "r") as file_reader:
    csv_reader = csv.DictReader(file_reader)
    for i in csv_reader:
        print(i, type(i))
# Out:
# {'culori': 'rosu', 'varste': '30', 'temperaturi': '18'} <class 'dict'>
# {'culori': 'verde', 'varste': '40', 'temperaturi': '25'} <class 'dict'>
