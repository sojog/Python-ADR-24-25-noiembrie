# %%
def functie():
    pass

# %%
print(functie)
# Out:
# <function functie at 0x10c91eda0>

# %%
functie()

# %%
x = None
print(x)
# Out:
# None

# %%
def adunare(x, y):
    return x + y

# %%
print(adunare)
# Out:
# <function adunare at 0x10c91f1c0>

# %%
adunare(10, 20)
# Out:
# 30

# %%
adunare("10", "20")
# Out:
# '1020'

# %%
## Python este loosly type
## Type hint
def ridica_la_putere(x:int, y:int) -> int:
    return x ** y

# %%
ridica_la_putere(2, 3)
# Out:
# 8

# %%
ridica_la_putere(3, 2)
# Out:
# 9

# %%
ridica_la_putere(3.5, 2)
# Out:
# 12.25
