# %% [markdown]
# # Secvente -> colectii ordonate

# %%
s = "hello world"
t = (1, 2, 3, "blue")
l = [1, 2, 3, "blue"]
g = range(10)

# %%
for i in s:
    print("i=", i)
# Out:
# i= h
# i= e
# i= l
# i= l
# i= o
# i=
# i= w
# i= o
# i= r
# i= l
# i= d

# %%
s = "hello world"
print(len(s))
# Out:
# 11

# %%
s[0]
# Out:
# 'h'
