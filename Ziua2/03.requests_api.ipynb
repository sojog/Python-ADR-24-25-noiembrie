# %%
import requests

# %%
URL = "https://api.chucknorris.io/jokes/random"

# %%
response = requests.get(URL)
response
# Out:
# <Response [200]>

# %%
response.content
# Out:
# b'{"categories":[],"created_at":"2020-01-05 13:42:26.766831","icon_url":"https://api.chucknorris.io/img/avatar/chuck-norris.png","id":"AToHZRkLRna5AVminFhzWQ","updated_at":"2020-01-05 13:42:26.766831","url":"https://api.chucknorris.io/jokes/AToHZRkLRna5AVminFhzWQ","value":"in 1974 Chuck Norris was charged with killing 15 students during a school shooting...with a spitball"}'

# %%
response.json()
# Out:
# {'categories': [],
#  'created_at': '2020-01-05 13:42:26.766831',
#  'icon_url': 'https://api.chucknorris.io/img/avatar/chuck-norris.png',
#  'id': 'AToHZRkLRna5AVminFhzWQ',
#  'updated_at': '2020-01-05 13:42:26.766831',
#  'url': 'https://api.chucknorris.io/jokes/AToHZRkLRna5AVminFhzWQ',
#  'value': 'in 1974 Chuck Norris was charged with killing 15 students during a school shooting...with a spitball'}

# %%
json_response = response.json()
type(json_response)
# Out:
# dict

# %%
json_response["value"]
# Out:
# 'in 1974 Chuck Norris was charged with killing 15 students during a school shooting...with a spitball'
