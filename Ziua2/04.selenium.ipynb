# %%
from selenium import webdriver

# %%
URL = "https://www.cursbnr.ro/"

# %%
browser = webdriver.Chrome()
browser
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="7dda01b620ad3eef04fea07c946d0d39")>

# %%
browser.get(URL)

# %%
# <p class="fc-button-label">Consimțământ</p>

# %%
from selenium.webdriver.common.by import By

# %%
cookie_xpath = "/html/body/div[6]/div[2]/div[2]/div[2]/div[2]/button[1]/p"

# %%
cookie_button = browser.find_element(By.XPATH, cookie_xpath)
cookie_button
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="7dda01b620ad3eef04fea07c946d0d39", element="f.9D4BC5104FD2837818EB3F3F9893957F.d.95E6E16F3877E1034F8C1E65CEAA69E3.e.382")>

# %%
cookie_button.click()

# %%
euro_xpath = "/html/body/div[3]/div[1]/div/main/div[2]/div[1]/ul/li[1]/div[1]/div[1]"

# %%
euro_div  = browser.find_element(By.XPATH, euro_xpath)
euro_div
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="7dda01b620ad3eef04fea07c946d0d39", element="f.9D4BC5104FD2837818EB3F3F9893957F.d.95E6E16F3877E1034F8C1E65CEAA69E3.e.889")>

# %%
euro_div.text
# Out:
# '1 EURO = 5.0871 Lei'

# %%
browser.quit()
