# %%
lista = [ 101, 22, 55, 10, 90, 81]
lista
# Out:
# [101, 22, 55, 10, 90, 81]

# %%
sorted(lista)
# Out:
# [10, 22, 55, 81, 90, 101]

# %%
lista
# Out:
# [101, 22, 55, 10, 90, 81]

# %%
lista.sort()

# %%
lista
# Out:
# [10, 22, 55, 81, 90, 101]
