# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.randint(1, 100, 10)
y = np.random.randint(1, 100, 10)
print("x=", x)
print("y=", y)
# Out:
# x= [19 58 66 53 82 82 79 60 26 36]
# y= [23 61 16 18 28 34  9 19 96 23]

# %%
df = pd.DataFrame({
    "col_x": x, "col_y": y 
})
df
# Out:
#    col_x  col_y
# 0     19     23
# 1     58     61
# 2     66     16
# 3     53     18
# 4     82     28
# 5     82     34
# 6     79      9
# 7     60     19
# 8     26     96
# 9     36     23

# %%
df.dtypes
# Out:
# col_x    int64
# col_y    int64
# dtype: object

# %%
x.dtype, y.dtype
# Out:
# (dtype('int64'), dtype('int64'))

# %%
plt.scatter( x, y )

# %%
plt.scatter( df["col_x"], df["col_y"] )

# %%
df.plot.scatter("col_x", "col_y")
# Out:
# <Axes: xlabel='col_x', ylabel='col_y'>
