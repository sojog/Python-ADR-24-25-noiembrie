# %%
import requests
import json

# %%
URL = "https://dummyjson.com/recipes"

# %%
response = requests.get(URL)
response
# Out:
# <Response [200]>

# %%
response.status_code
# Out:
# 200

# %%
response.content
# Out:
# b'{"recipes":[{"id":1,"name":"Classic Margherita Pizza","ingredients":["Pizza dough","Tomato sauce","Fresh mozzarella cheese","Fresh basil leaves","Olive oil","Salt and pepper to taste"],"instructions":["Preheat the oven to 475\xc2\xb0F (245\xc2\xb0C).","Roll out the pizza dough and spread tomato sauce evenly.","Top with slices of fresh mozzarella and fresh basil leaves.","Drizzle with olive oil and season with salt and pepper.","Bake in the preheated oven for 12-15 minutes or until the crust is golden brown.","Slice and serve hot."],"prepTimeMinutes":20,"cookTimeMinutes":15,"servings":4,"difficulty":"Easy","cuisine":"Italian","caloriesPerServing":300,"tags":["Pizza","Italian"],"userId":166,"image":"https://cdn.dummyjson.com/recipe-images/1.webp","rating":4.6,"reviewCount":98,"mealType":["Dinner"]},{"id":2,"name":"Vegetarian Stir-Fry","ingredients":["Tofu, cubed","Broccoli florets","Carrots, sliced","Bell peppers, sliced","Soy sauce","Ginger, minced","Garlic, minced","Sesame oil","Co
# ...

# %%
response.text
# Out:
# '{"recipes":[{"id":1,"name":"Classic Margherita Pizza","ingredients":["Pizza dough","Tomato sauce","Fresh mozzarella cheese","Fresh basil leaves","Olive oil","Salt and pepper to taste"],"instructions":["Preheat the oven to 475°F (245°C).","Roll out the pizza dough and spread tomato sauce evenly.","Top with slices of fresh mozzarella and fresh basil leaves.","Drizzle with olive oil and season with salt and pepper.","Bake in the preheated oven for 12-15 minutes or until the crust is golden brown.","Slice and serve hot."],"prepTimeMinutes":20,"cookTimeMinutes":15,"servings":4,"difficulty":"Easy","cuisine":"Italian","caloriesPerServing":300,"tags":["Pizza","Italian"],"userId":166,"image":"https://cdn.dummyjson.com/recipe-images/1.webp","rating":4.6,"reviewCount":98,"mealType":["Dinner"]},{"id":2,"name":"Vegetarian Stir-Fry","ingredients":["Tofu, cubed","Broccoli florets","Carrots, sliced","Bell peppers, sliced","Soy sauce","Ginger, minced","Garlic, minced","Sesame oil","Cooked rice for s
# ...

# %%
with open("05.recipes.json", "w") as file_writer:
    json.dump(response.text, file_writer)

# %%
response_dict = response.json()
response_dict
# Out:
# {'recipes': [{'id': 1,
#    'name': 'Classic Margherita Pizza',
#    'ingredients': ['Pizza dough',
#     'Tomato sauce',
#     'Fresh mozzarella cheese',
#     'Fresh basil leaves',
#     'Olive oil',
#     'Salt and pepper to taste'],
#    'instructions': ['Preheat the oven to 475°F (245°C).',
#     'Roll out the pizza dough and spread tomato sauce evenly.',
#     'Top with slices of fresh mozzarella and fresh basil leaves.',
#     'Drizzle with olive oil and season with salt and pepper.',
#     'Bake in the preheated oven for 12-15 minutes or until the crust is golden brown.',
#     'Slice and serve hot.'],
#    'prepTimeMinutes': 20,
#    'cookTimeMinutes': 15,
#    'servings': 4,
#    'difficulty': 'Easy',
#    'cuisine': 'Italian',
#    'caloriesPerServing': 300,
#    'tags': ['Pizza', 'Italian'],
#    'userId': 166,
#    'image': 'https://cdn.dummyjson.com/recipe-images/1.webp',
#    'rating': 4.6,
#    'reviewCount': 98,
#    'mealType': ['Dinner']},
#   {'id': 2,
# ...

# %%
response_dict.keys()
# Out:
# dict_keys(['recipes', 'total', 'skip', 'limit'])

# %%
response_dict["recipes"]
# Out:
# [{'id': 1,
#   'name': 'Classic Margherita Pizza',
#   'ingredients': ['Pizza dough',
#    'Tomato sauce',
#    'Fresh mozzarella cheese',
#    'Fresh basil leaves',
#    'Olive oil',
#    'Salt and pepper to taste'],
#   'instructions': ['Preheat the oven to 475°F (245°C).',
#    'Roll out the pizza dough and spread tomato sauce evenly.',
#    'Top with slices of fresh mozzarella and fresh basil leaves.',
#    'Drizzle with olive oil and season with salt and pepper.',
#    'Bake in the preheated oven for 12-15 minutes or until the crust is golden brown.',
#    'Slice and serve hot.'],
#   'prepTimeMinutes': 20,
#   'cookTimeMinutes': 15,
#   'servings': 4,
#   'difficulty': 'Easy',
#   'cuisine': 'Italian',
#   'caloriesPerServing': 300,
#   'tags': ['Pizza', 'Italian'],
#   'userId': 166,
#   'image': 'https://cdn.dummyjson.com/recipe-images/1.webp',
#   'rating': 4.6,
#   'reviewCount': 98,
#   'mealType': ['Dinner']},
#  {'id': 2,
#   'name': 'Vegetarian Stir-Fry',
# ...

# %%
len(response_dict["recipes"])
# Out:
# 30

# %% [markdown]
# # pip install pandas

# %%
import pandas as pd

# %%
print(pd.__doc__)
# Out:
# pandas - a powerful data analysis and manipulation library for Python
# ...
#
# **pandas** is a Python package providing fast, flexible, and expressive data
# structures designed to make working with "relational" or "labeled" data both
# easy and intuitive. It aims to be the fundamental high-level building block for
# doing practical, **real world** data analysis in Python. Additionally, it has
# the broader goal of becoming **the most powerful and flexible open source data
# analysis / manipulation tool available in any language**. It is already well on
# its way toward this goal.
#
# Main Features
# -------------
# Here are just a few of the things that pandas does well:
#
#   - Easy handling of missing data in floating point as well as non-floating
#     point data.
#   - Size mutability: columns can be inserted and deleted from DataFrame and
#     higher dimensional objects
#   - Automatic and explicit data alignment: objects can be explicitly aligned
# ...

# %%
df = pd.DataFrame(response_dict["recipes"])
df.head()
# Out:
#    id                      name  \
# 0   1  Classic Margherita Pizza
# 1   2       Vegetarian Stir-Fry
# 2   3    Chocolate Chip Cookies
# 3   4     Chicken Alfredo Pasta
# 4   5       Mango Salsa Chicken
#
#                                          ingredients  \
# 0  [Pizza dough, Tomato sauce, Fresh mozzarella c...
# 1  [Tofu, cubed, Broccoli florets, Carrots, slice...
# 2  [All-purpose flour, Butter, softened, Brown su...
# 3  [Fettuccine pasta, Chicken breast, sliced, Hea...
# 4  [Chicken thighs, Mango, diced, Red onion, fine...
#
#                                         instructions  prepTimeMinutes  \
# 0  [Preheat the oven to 475°F (245°C)., Roll out ...               20
# 1  [In a wok, heat sesame oil over medium-high he...               15
# 2  [Preheat the oven to 350°F (175°C)., In a bowl...               15
# 3  [Cook fettuccine pasta according to package in...               15
# 4  [Season chicken thighs with salt and pepper., ...               15
#
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.to_csv("05.recipes.csv")

# %%
df.head(3)
# Out:
#    id                      name  \
# 0   1  Classic Margherita Pizza
# 1   2       Vegetarian Stir-Fry
# 2   3    Chocolate Chip Cookies
#
#                                          ingredients  \
# 0  [Pizza dough, Tomato sauce, Fresh mozzarella c...
# 1  [Tofu, cubed, Broccoli florets, Carrots, slice...
# 2  [All-purpose flour, Butter, softened, Brown su...
#
#                                         instructions  prepTimeMinutes  \
# 0  [Preheat the oven to 475°F (245°C)., Roll out ...               20
# 1  [In a wok, heat sesame oil over medium-high he...               15
# 2  [Preheat the oven to 350°F (175°C)., In a bowl...               15
#
#    cookTimeMinutes  servings difficulty   cuisine  caloriesPerServing  \
# 0               15         4       Easy   Italian                 300
# 1               20         3     Medium     Asian                 250
# 2               10        24       Easy  American                 150
#
#                             tags  userId  \
# ...

# %%
df.keys()
# Out:
# Index(['id', 'name', 'ingredients', 'instructions', 'prepTimeMinutes',
#        'cookTimeMinutes', 'servings', 'difficulty', 'cuisine',
#        'caloriesPerServing', 'tags', 'userId', 'image', 'rating',
#        'reviewCount', 'mealType'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                      int64
# name                   object
# ingredients            object
# instructions           object
# prepTimeMinutes         int64
# cookTimeMinutes         int64
# servings                int64
# difficulty             object
# cuisine                object
# caloriesPerServing      int64
# tags                   object
# userId                  int64
# image                  object
# rating                float64
# reviewCount             int64
# mealType               object
# dtype: object

# %%
prep_difficulty_df = df[["name", "prepTimeMinutes", "difficulty"]]
prep_difficulty_df.head(2)
# Out:
#                        name  prepTimeMinutes difficulty
# 0  Classic Margherita Pizza               20       Easy
# 1       Vegetarian Stir-Fry               15     Medium

# %%
df.head(2)
# Out:
#    id                      name  \
# 0   1  Classic Margherita Pizza
# 1   2       Vegetarian Stir-Fry
#
#                                          ingredients  \
# 0  [Pizza dough, Tomato sauce, Fresh mozzarella c...
# 1  [Tofu, cubed, Broccoli florets, Carrots, slice...
#
#                                         instructions  prepTimeMinutes  \
# 0  [Preheat the oven to 475°F (245°C)., Roll out ...               20
# 1  [In a wok, heat sesame oil over medium-high he...               15
#
#    cookTimeMinutes  servings difficulty  cuisine  caloriesPerServing  \
# 0               15         4       Easy  Italian                 300
# 1               20         3     Medium    Asian                 250
#
#                             tags  userId  \
# 0               [Pizza, Italian]     166
# 1  [Vegetarian, Stir-fry, Asian]     143
#
#                                             image  rating  reviewCount  \
# 0  https://cdn.dummyjson.com/recipe-images/1.webp     4.6           98
# ...

# %%
easy_df = df[  df["difficulty"] == "Easy"  ]
easy_df.shape
# Out:
# (14, 16)

# %%
df["servings"].min()
# Out:
# np.int64(1)

# %%
df["servings"].max()
# Out:
# np.int64(24)

# %%
df["servings"].unique()
# Out:
# array([ 4,  3, 24,  6,  2,  5,  1])

# %%
df.describe()
# Out:
#               id  prepTimeMinutes  cookTimeMinutes   servings  \
# count  30.000000        30.000000        30.000000  30.000000
# mean   15.500000        21.500000        19.500000   4.366667
# std     8.803408         9.751216        12.821722   3.978245
# min     1.000000         5.000000         0.000000   1.000000
# 25%     8.250000        15.000000        11.250000   3.000000
# 50%    15.500000        20.000000        20.000000   4.000000
# 75%    22.750000        30.000000        28.750000   4.000000
# max    30.000000        45.000000        45.000000  24.000000
#
#        caloriesPerServing      userId     rating  reviewCount
# count           30.000000   30.000000  30.000000    30.000000
# mean           331.333333  107.633333   4.616667    51.633333
# std            122.776313   57.135340   0.219848    30.673456
# min            120.000000    1.000000   4.200000     0.000000
# 25%            227.500000   55.750000   4.425000    27.000000
# ...

# %%
df.dtypes
# Out:
# id                      int64
# name                   object
# ingredients            object
# instructions           object
# prepTimeMinutes         int64
# cookTimeMinutes         int64
# servings                int64
# difficulty             object
# cuisine                object
# caloriesPerServing      int64
# tags                   object
# userId                  int64
# image                  object
# rating                float64
# reviewCount             int64
# mealType               object
# dtype: object

# %%
short_df = df[["name", "difficulty", "servings"]]
short_df["coeficient"] = short_df["difficulty"].map({ "Easy":0.5, "Medium":1.2 })
short_df["calcul"] = short_df["coeficient"] * short_df["servings"] / 100
short_df
# Out:
# /var/folders/3k/f_77v9pn1r94_xmvm2w3xgqr0000gn/T/ipykernel_3772/1207398068.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_df["coeficient"] = short_df["difficulty"].map({ "Easy":0.5, "Medium":1.2 })
# /var/folders/3k/f_77v9pn1r94_xmvm2w3xgqr0000gn/T/ipykernel_3772/1207398068.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_df["calcul"] = short_df["coeficient"] * short_df["servings"] / 100
#                                  name difficulty  servings  coeficient  calcul
# ...

# %%
short_df.isnull().sum()
# Out:
# name          0
# difficulty    0
# servings      0
# coeficient    0
# calcul        0
# dtype: int64

# %%
short_df.fillna()

# %%
short_df.pivot(columns=["difficulty"])
# Out:
#                                    name                                     \
# difficulty                         Easy                             Medium
# 0              Classic Margherita Pizza                                NaN
# 1                                   NaN                Vegetarian Stir-Fry
# 2                Chocolate Chip Cookies                                NaN
# 3                                   NaN              Chicken Alfredo Pasta
# 4                   Mango Salsa Chicken                                NaN
# 5             Quinoa Salad with Avocado                                NaN
# 6               Tomato Basil Bruschetta                                NaN
# 7                                   NaN         Beef and Broccoli Stir-Fry
# 8                         Caprese Salad                                NaN
# 9                                   NaN                Shrimp Scampi Pasta
# ...

# %%
short_df.agg("count")
# Out:
# name          30
# difficulty    30
# servings      30
# coeficient    30
# calcul        30
# dtype: int64
