# %%
# Trebuie creată clasa STBCard care reprezintă cardul de la regia autonomă de transport București. 
# Atributele necesare sunt: numele deținătorului, călătorii disponibile și creditul disponibil
# În cazul in care nu primește numele deținătorului, setati-l automat pe "Nenominal"
# Setați valoarea unei călătorii validate cu credit la 3 lei. # STATICA
# Creați funcții automate pentru validare cu credit/validare călătorie și reîncare credit/reîncarcare călătorii

# %%
class STBCard:
    """ Aceasta este documentatia pentru clasa STBCard
    """
    VALOARE_CALATORIE  = 3

    # self -> echivalent this
    # __init__ -> functii magice 
    # "__" -> privata
    def __init__(self, nume = "Nenominal", credit = 0, calatorii = 0):
        ## Variabila cu 1 singur "_" este interna sau protected
        ## "_" -> nu trebuie modificat din exteriorul clasei
        self._nume = nume

        ## Variabila cu 2 "_" este privata
         ## "__" -> nu trebuie modificat din exteriorul clasei
        self.__credit = credit
        self.__calatorii = calatorii

    def __str__(self):
        return f" {self._nume} are {self.__credit} lei credit si {self.__calatorii} nr de calatorii "

# %%
obiect1 = STBCard("Mihai")
obiect1

# %%
obiect1._nume
# Out:
# 'Mihai'

# %%
print(obiect1)
# Out:
#  Mihai are 0 lei credit si 0 nr de calatorii

# %%
obiect2 = STBCard("Andreea")
obiect2

# %%
obiect2._nume
# Out:
# 'Andreea'

# %%
obiect3 = STBCard()
obiect3

# %%
obiect3.credit = 3

# %%
print(obiect3)
# Out:
#  Nenominal are 0 lei credit si 0 nr de calatorii

# %%
obiect3.__credit = "infinita"

# %%
obiect3.orice_variabila = "hello"

# %%
obiect3.orice_variabila
# Out:
# 'hello'

# %%
print(obiect3)
# Out:
#  Nenominal are 0 lei credit si 0 nr de calatorii

# %%
obiect3._nume = [312]

# %%
obiect2._nume
# Out:
# 'Andreea'

# %%
obiect2.__credit
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[144], line 1
# ----> 1 obiect2.__credit
#
# AttributeError: 'STBCard' object has no attribute '__credit'

# %% [markdown]
# # Name mangling

# %%
obiect2._STBCard__credit
# Out:
# 0

# %%
print(STBCard.__doc__)
# Out:
# Aceasta este documentatia pentru clasa STBCard

# %%
help(STBCard)
# Out:
# Help on class STBCard in module __main__:
#
# class STBCard(builtins.object)
#  |  STBCard(nume='Nenominal', credit=0, calatorii=0)
#  |
#  |  Aceasta este documentatia pentru clasa STBCard
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, nume='Nenominal', credit=0, calatorii=0)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __str__(self)
#  |      Return str(self).
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  VALOARE_CALATORIE = 3
