# %%
import time

# %%
time.time()
# Out:
# 1764065835.142354

# %%
start_time = time.time()
print("start_time", start_time)
time.sleep(3)

stop_time = time.time()

print("stop_time", stop_time)
print("delta", stop_time - start_time)
# Out:
# start_time 1764065900.571444
# stop_time 1764065903.577033
# delta 3.005589008331299

# %%
import datetime

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2025, 11, 25, 12, 18, 50, 714796)

# %%
year = datetime.datetime.now().year
print(year)
# Out:
# 2025

# %%
new_date = datetime.datetime(2026, 7,3,0, 0, 0)
new_date
# Out:
# datetime.datetime(2026, 7, 3, 0, 0)

# %%
now = datetime.datetime.now()
now
# Out:
# datetime.datetime(2025, 11, 25, 12, 20, 9, 973849)

# %%
new_date - now
# Out:
# datetime.timedelta(days=219, seconds=41990, microseconds=26151)
