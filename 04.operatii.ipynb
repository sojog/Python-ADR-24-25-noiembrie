# %%
x = 20
print(x)
# Out:
# 20

# %%
y = x / 2
print(y)
# Out:
# 10.0

# %%
print(x)
# Out:
# 20

# %% [markdown]
# # Acesta este un markdown

# %%
# Aceasta este o celula normala

# %%
10 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 10 / 0
#
# ZeroDivisionError: division by zero
