# %%
x = True
print(x, type(x))
# Out:
# True <class 'bool'>

# %%
x = False
print(x, type(x))
# Out:
# False <class 'bool'>

# %% [markdown]
# # Bool to others

# %%
x = True
x = int(x)
print(x,type(x))
# Out:
# 1 <class 'int'>

# %%
x = False
x = int(x)
print(x,type(x))
# Out:
# 0 <class 'int'>

# %%
x = True
x = float(x)
print(x,type(x))
# Out:
# 1.0 <class 'float'>

# %%
x = True
x = str(x)
print(x,type(x))
# Out:
# True <class 'str'>

# %% [markdown]
# # Others to bool

# %%
x = 1
x = bool(x)
print(x,type(x))
# Out:
# True <class 'bool'>

# %%
x = 0
x = bool(x)
print(x,type(x))
# Out:
# False <class 'bool'>

# %%
x = 132
x = bool(x)
print(x,type(x))
# Out:
# True <class 'bool'>

# %%
x = -1312
x = bool(x)
print(x,type(x))
# Out:
# True <class 'bool'>

# %%
x = 1.321
x = bool(x)
print(x,type(x))
# Out:
# True <class 'bool'>

# %%
x = 0.0
x = bool(x)
print(x,type(x))
# Out:
# False <class 'bool'>

# %%
x = "hello"
x = bool(x)
print(x,type(x))
# Out:
# True <class 'bool'>

# %%
x = ""
x = bool(x)
print(x,type(x))
# Out:
# False <class 'bool'>

# %%
x = " "
x = bool(x)
print(x,type(x))
# Out:
# True <class 'bool'>

# %%
x = "0"
x = bool(x)
print(x,type(x))
# Out:
# True <class 'bool'>
