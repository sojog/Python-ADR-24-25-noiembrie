# %%
print("Hello")
# Out:
# Hello

# %%
f = print

# %%
print(f)
# Out:
# <built-in function print>

# %%
f("salutare")
# Out:
# salutare

# %%
def adunare(x, y):
    return x + y

# %%
def scadere(x, y):
    return x - y

# %%
def inmultire(x, y):
    return x * y

# %%
def operatie(functia, x, y):
    return functia(x, y)

# %%
operatie(adunare, 10, 6)
# Out:
# 16

# %%
operatie(inmultire, 10, 6)
# Out:
# 60

# %%
operatie(scadere, 10, 6)
# Out:
# 4
